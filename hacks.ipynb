# %%
import os
import sys
import json
import csv

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %%
#GET AN ARTICLE ITEM FROM A HANDLE, WE CAN GET DE ITEM ID
url = 'https://digitallibrary.amnh.org/rest/handle/2246/6634'

result = os.popen('curl -ki -H "Accept: application/json" -H "Content-Type: application/json" \-X GET ' + url).read()

parseData = json.loads(result[199:])
parseData
# Out:
# {u'archived': u'true',
#  u'bitstreams': None,
#  u'expand': [u'metadata',
#   u'parentCollection',
#   u'parentCollectionList',
#   u'parentCommunityList',
#   u'bitstreams',
#   u'all'],
#  u'handle': u'2246/6634',
#  u'id': 6709,
#  u'lastModified': u'2016-02-08 11:22:09.326',
#  u'link': u'/RESTapi/items/6709',
#  u'name': u'Morphological variation in a unisexual whiptail lizard (Aspidoscelis exsanguis) and one of its bisexual parental species (Aspidoscelis inornata) (Reptilia, Squamata, Teiidae) : is the clonal species less variable? (American Museum novitates, no. 3849)',
#  u'parentCollection': None,
#  u'parentCollectionList': None,
#  u'parentCommunityList': None,
#  u'type': u'item',
#  u'withdrawn': u'false'}

# %%
#GET THE IDEM USING THE ID 6709, GET THE BISTSTREAM INFO
url = 'https://digitallibrary.amnh.org/rest/items/6709/bitstreams'
result = os.popen('curl -ki -H "Accept: application/json" -H "Content-Type: application/json" \-X GET ' + url).read()
parseData = json.loads(result[199:])
parseData
# Out:
# [{u'bundleName': u'LICENSE',
#   u'checkSum': {u'checkSumAlgorithm': u'MD5',
#    u'value': u'8a4605be74aa9ea9d79846c1fba20a33'},
#   u'description': None,
#   u'expand': [u'parent', u'policies', u'all'],
#   u'format': u'License',
#   u'handle': None,
#   u'id': 21285,
#   u'link': u'/RESTapi/bitstreams/21285',
#   u'mimeType': u'text/plain',
#   u'name': u'license.txt',
#   u'parentObject': None,
#   u'policies': None,
#   u'retrieveLink': u'/bitstreams/21285/retrieve',
#   u'sequenceId': 4,
#   u'sizeBytes': 1748,
#   u'type': u'bitstream'},
#  {u'bundleName': u'ORIGINAL',
#   u'checkSum': {u'checkSumAlgorithm': u'MD5',
#    u'value': u'42abf830f4d705e4a84a9f251bebf8ef'},
#   u'description': u'',
#   u'expand': [u'parent', u'policies', u'all'],
#   u'format': u'Adobe PDF',
#   u'handle': None,
#   u'id': 21282,
#   u'link': u'/RESTapi/bitstreams/21282',
#   u'mimeType': u'application/pdf',
#   u'name': u'N3849.pdf',
#   u'parentObject': None,
#   u'policies': None,
# ...

# %%
#GET THE ORIGINAL FILE USING THE BITSTREAM ID 21282, GET THE FILE
url = 'https://digitallibrary.amnh.org/rest/bitstreams/21282/retrieve'
result = os.popen('curl -ki -H "Accept: application/json" -H "Content-Type: application/json" \-X GET ' + url).read()

# %%
# Out:
# 'HTTP/1.1 200 OK\r\nDate: Sat, 19 Nov 2016 21:33:36 GMT\r\nCache-Control: private\r\nExpires: Wed, 31 Dec 1969 19:00:00 EST\r\nContent-Type: application/pdf\r\nConnection: close\r\nTransfer-Encoding: chunked\r\n\r\n%PDF-1.5\r%\xe2\xe3\xcf\xd3\r\n127 0 obj\r<</Linearized 1/L 205750/O 130/E 35413/N 20/T 203094/H [ 756 440]>>\rendobj\r              \rxref\r127 23\r0000000016 00000 n\r\n0000001196 00000 n\r\n0000001328 00000 n\r\n0000001364 00000 n\r\n0000001717 00000 n\r\n0000002268 00000 n\r\n0000003138 00000 n\r\n0000003602 00000 n\r\n0000003639 00000 n\r\n0000003751 00000 n\r\n0000004002 00000 n\r\n0000004783 00000 n\r\n0000005596 00000 n\r\n0000005736 00000 n\r\n0000006150 00000 n\r\n0000006651 00000 n\r\n0000009716 00000 n\r\n0000012365 00000 n\r\n0000024361 00000 n\r\n0000030367 00000 n\r\n0000034483 00000 n\r\n0000034907 00000 n\r\n0000000756 00000 n\r\ntrailer\r<</Size 150/Root 128 0 R/Info 126 0 R/ID[<3485D2F68B1B4126A2918E94C9183D60><E63C7EEF94FC485CB6B3910165F23F8B>]/Prev 203
# ...
